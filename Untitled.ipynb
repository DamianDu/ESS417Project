# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
from scipy import stats

# %%
##load in the data 
x = pd.read_csv('graph.csv', sep=';')

# %%
x
# Out:
#    Forest  year
# 0  800000  2015
# 1  756000  2016
# 2  646879  2017
# 3  603410  2018
# 4  480000  2019
# 5  400000  2020
# 6  375000  2021
# 7  350000  2022
# 8  340000  2023
# 9  300000  2024

# %%
plt.title('Estimated total change in forest 2015-2024')
plt.plot(x['year'], x['Forest'], linestyle = 'dotted')
plt.xlabel('Year')
plt.ylabel('Forest Area [$m^2$]')
plt.show()

# %%
##load in the data 
y = pd.read_csv('relativechange.csv', sep=';')

# %%
plt.title('Estimated yearly change in forest 2015-2024')
plt.plot(y['year'], y['Forest'], linestyle = 'dotted')
plt.ylabel('Forest Area [$m^2$]')
plt.xlabel('Year')
plt.show()
